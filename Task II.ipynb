# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### reading and understanding data

# %%
data = pd.read_csv("cereal.csv")
data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
data.shape
# Out:
# (77, 16)

# %%
#overall data distribution
plt.figure()
plt.title("overall cereals data distribution")
sns.histplot(data=data)
# Out:
# <AxesSubplot:title={'center':'overall cereals data distribution'}, ylabel='Count'>

# %%
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# ### analyzing feature wise distribution of data

# %%
def plot_histogram(column_data, column_name):
    plt.figure()
    plt.title(f"Distribution of {column_name}")
    sns.histplot(column_data, kde=True) 
    plt.show()

# %%
# in view of manufactures
plot_histogram(data['mfr'],'Manufacturer')

# %%
# in view of calories
plot_histogram(data['calories'],'Calories')

# %%
# in view of type of cereal
plot_histogram(data['type'], 'Cold or Hot Types of Cereal')

# %%
plot_histogram(data['protein'], 'Protein')

# %%
plot_histogram(data['fat'], 'Fat')

# %%
plot_histogram(data['sodium'], 'Sodium')

# %%
plot_histogram(data['fiber'], 'Fiber')

# %%
plot_histogram(data['carbo'], 'Carbohydrates')

# %%
plot_histogram(data['sugars'], 'Sugar')

# %%
plot_histogram(data['potass'], 'Potassium')

# %%
plot_histogram(data['vitamins'], 'Vitamins')

# %%
plot_histogram(data['cups'], 'Cups')

# %%
plot_histogram(data['rating'], 'Consumer Rating')

# %% [markdown]
# ### to analyze the data more through relationship and importance of features

# %%
cereals_sorted = data.sort_values(by='rating', ascending=False)

plt.figure(figsize=(14,5))
plt.title("brands and their titles")
plt.xticks(rotation=90)
sns.barplot(data = cereals_sorted, x = cereals_sorted['name'], y = cereals_sorted['rating'])
plt.show()

# %% [markdown]
# ###### Top five brands with the highest ratings are:
#
# All-Bran with Extra Fiber
#
# Shredded Wheat 'n' Bran
#
# Shredded Wheat Spoon Size
#
# 100% Bran
#
# Shredded Wheat

# %%
# sugar and rating relationship

plt.figure()
plt.title('Relationship between Sugar Content and Rating')
plt.xticks(rotation=90)
sns.regplot(data=data, x=data['sugars'], y=data['rating'])
# Out:
# <AxesSubplot:title={'center':'Relationship between Sugar Content and Rating'}, xlabel='sugars', ylabel='rating'>

# %% [markdown]
# ###### there appears to be a positive correlation between lower sugar content and higher cereal ratings.

# %%
#knowing relation between features with correlation model

numeric_cols = data.drop(columns=['name', 'type', 'mfr','shelf', 'cups', 'weight'])

# %%
correlation_matrix = numeric_cols.corr(method = 'pearson')

# Create a heatmap for correlation with 'rating'
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix[['rating']].sort_values(by='rating', ascending=False), annot=True)
plt.title("Correlation Heatmap with Ratings")
plt.show()

# %% [markdown]
# ###### Our heatmap reveals significant insights into the factors influencing consumer ratings. Fiber, protein, potassium, and carbohydrates exhibit a positive linear relationship with ratings. Conversely, vitamins, sodium, fat, calories, and sugars display a negative correlation

# %%
#checking feature importance with random forest method

x = numeric_cols.drop(columns = ['rating'])
y = data['rating']

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
feature_importances = model.feature_importances_

plt.figure(figsize=(6, 3))
sns.barplot(x=feature_importances, y=x.columns)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importances")
plt.show()

# %% [markdown]
# ###### Through the utilization of a Random Forest Regressor, we gain valuable insights into which features wield the greatest influence on predicting consumer ratings. The bar chart showcases sugars and calories as two pivotal factors contributing to our ability to forecast ratings.
